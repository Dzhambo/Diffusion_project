# %%
import sys
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
sys.path.append('../../')

import numpy as np
import random
from IPython.display import Image

import torch
from torch.utils.data import DataLoader

from torchvision.datasets import CIFAR10

from utils import show_first_batch, transform_data_for_show, show_forward, training, show_images, generate_new_images
from diffusion_models.ddpm import CustomDiffusionModel
from reverse_models.simple_unet.unet import CustomUnet
from metrics.rate_score import rate_score
from metrics.inception_score import inception_score
from metrics.fid_score import fid_score



SEED = 0
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
min_beta, max_beta = 10 ** -4, 0.02

# %% [markdown]
# # Read  and prepare dataset

# %%
dataset = transform_data_for_show(CIFAR10, store_path='../../datasets')
train_dataloader = DataLoader(dataset, batch_size=128, num_workers=0, shuffle=True)
show_first_batch(train_dataloader)
# Out:
# Files already downloaded and verified

# %%
image_channels = next(iter(train_dataloader))[0].size()[1]
image_channels
# Out:
# 3

# %% [markdown]
# # N_STEPS = 1000

# %%
n_steps = 1000

ddpm = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, min_beta=min_beta, max_beta=max_beta, device=device)
show_forward(ddpm, train_dataloader, device)

# %% [markdown]
# ### Train

# %%
optimizer = torch.optim.Adam(ddpm.parameters(), lr=0.001)     
training(ddpm, train_dataloader, display=True, n_epochs=20, upset_epoch=5, device=device, optimizer=optimizer, store_path = '../../model_weights/ddpm_cifar_steps_1000.pt')
# Out:
# Loss at epoch 16: 0.03574 --> Best model ever (stored)
# Epoch 17/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 17: 0.03650
# Epoch 18/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 18: 0.03565 --> Best model ever (stored)
# Epoch 19/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 19: 0.03606
# Epoch 20/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 20: 0.03655

# %% [markdown]
# ### Test

# %%
store_path = '../../model_weights/ddpm_cifar_steps_1000.pt'

best_model = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, device=device)
best_model.load_state_dict(torch.load(store_path, map_location=device))
best_model.eval()
print("Model loaded")
# Out:
# Model loaded

# %%
print("Generating new images")
generated = generate_new_images(
        best_model,
        n_samples=100,
        device=device,
        gif_name="../../pictures/cifar_1000.gif",
        c=3, h=32, w=32
    )
show_images(generated, title="Final result")
# Out:
# Generating new images

# %%
Image(open('../../pictures/cifar_1000.gif', 'rb').read())

# %% [markdown]
# ### Metrics

# %%
print('bits_per_pixel = {}, N = 100, n_step = 1000'.format(rate_score(generated)))
score, std = inception_score(generated, device=device, resize=True, splits=10)
print('inception_score = {}, inception_std = {}, N = 100, n_step = 1000'.format(score, std))
# Out:
# bits_per_pixel = 6.777584075927734, N = 100, n_step = 1000
# inception_score = 2.1431146910372645, inception_std = 0.29517615242654915, N = 100, n_step = 1000
# ../../metrics/inception_score.py:14: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x).data.cpu().numpy()

# %% [markdown]
# # N_STEPS = 500

# %%
n_steps = 500

ddpm = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, min_beta=min_beta, max_beta=max_beta, device=device)
show_forward(ddpm, train_dataloader, device)

# %% [markdown]
# ### Train

# %%
optimizer = torch.optim.Adam(ddpm.parameters(), lr=0.001)     
training(ddpm, train_dataloader, display=True, n_epochs=20, device=device, optimizer=optimizer, upset_epoch=5, store_path = '../../model_weights/ddpm_cifar_steps_500.pt')
# Out:
# Loss at epoch 16: 0.05092 --> Best model ever (stored)
# Epoch 17/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 17: 0.05038 --> Best model ever (stored)
# Epoch 18/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 18: 0.05125
# Epoch 19/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 19: 0.05045
# Epoch 20/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 20: 0.05018 --> Best model ever (stored)

# %% [markdown]
# ### Test

# %%
store_path = '../../model_weights/ddpm_cifar_steps_500.pt'

best_model = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, device=device)
best_model.load_state_dict(torch.load(store_path, map_location=device))
best_model.eval()
print("Model loaded")
# Out:
# Model loaded

# %%
print("Generating new images")
generated = generate_new_images(
        best_model,
        n_samples=100,
        device=device,
        gif_name="../../pictures/cifar_500.gif",
        c=3, h=32, w=32
    )
show_images(generated, title="Final result")
# Out:
# Generating new images

# %%
Image(open('../../pictures/cifar_500.gif', 'rb').read())

# %% [markdown]
# ### Metrics

# %%
print('bits_per_pixel = {}, N = 100, n_step = 500'.format(rate_score(generated)))
score, std = inception_score(generated, device=device, resize=True, splits=10)
print('inception_score = {}, inception_std = {}, N = 100, n_step = 500'.format(score, std))
# Out:
# bits_per_pixel = 6.8068389892578125, N = 100, n_step = 500
# inception_score = 2.213988611059082, inception_std = 0.22773233703854914, N = 100, n_step = 500

# %% [markdown]
# # N_STEPS = 2000

# %%
n_steps = 2000

ddpm = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, min_beta=min_beta, max_beta=max_beta, device=device)
show_forward(ddpm, train_dataloader, device)

# %% [markdown]
# ### Train

# %%
optimizer = torch.optim.Adam(ddpm.parameters(), lr=0.001)     
training(ddpm, train_dataloader, display=True, n_epochs=20, device=device, upset_epoch=5, optimizer=optimizer, store_path = '../../model_weights/ddpm_cifar_steps_2000.pt')
# Out:
# Loss at epoch 16: 0.02550
# Epoch 17/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 17: 0.02508 --> Best model ever (stored)
# Epoch 18/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 18: 0.02560
# Epoch 19/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 19: 0.02479 --> Best model ever (stored)
# Epoch 20/20:   0%|          | 0/391 [00:00<?, ?it/s]
# Loss at epoch 20: 0.02500

# %% [markdown]
# ### Test

# %%
store_path = '../../model_weights/ddpm_cifar_steps_2000.pt'

best_model = CustomDiffusionModel(CustomUnet(image_channels), n_steps=n_steps, device=device)
best_model.load_state_dict(torch.load(store_path, map_location=device))
best_model.eval()
print("Model loaded")
# Out:
# Model loaded

# %%
print("Generating new images")
generated = generate_new_images(
        best_model,
        n_samples=100,
        device=device,
        gif_name="../../pictures/cifar_2000.gif",
        c=3, h=32, w=32
    )
show_images(generated, title="Final result")
# Out:
# Generating new images

# %%
Image(open('../../pictures/cifar_2000.gif', 'rb').read())

# %% [markdown]
# ### Metrics

# %%
print('bits_per_pixel = {}, N = 100, n_step = 2000'.format(rate_score(generated)))
score, std = inception_score(generated, device=device, resize=True, splits=10)
print('inception_score = {}, inception_std = {}, N = 100, n_step = 2000'.format(score, std))
# Out:
# bits_per_pixel = 6.7809977531433105, N = 100, n_step = 2000
# inception_score = 2.3614381899047063, inception_std = 0.3345370051134381, N = 100, n_step = 2000
